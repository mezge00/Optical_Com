# %%
# Receiver Code (receiver.py)
import serial
import sys
import time

# Open the serial port
ser = serial.Serial('COM7', 9600, timeout=1)

print("Receiver started. Listening for incoming data...")

while True:
    # Read the incoming data
    data = ser.read(1024)

    # Decode the data using ASCII decoding
    decoded_data = data.decode('ascii', errors='ignore')

    # Print the received data
    print(decoded_data, end='')

    # Flush the buffer to ensure timely printing
    sys.stdout.flush()

# Close the serial port (not reached in this case, but good practice)
ser.close()
# Out:
# Receiver started. Listening for incoming data...
# |8|@8D@vfx<
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3108\1402375261.py in <module>
#      11 while True:
#      12     # Read the incoming data
# ---> 13     data = ser.read(1024)
#      14
#      15     # Decode the data using ASCII decoding
#
# C:\ProgramData\Anaconda3\lib\site-packages\serial\serialwin32.py in read(self, size)
#     286                 if not read_ok and win32.GetLastError() not in (win32.ERROR_SUCCESS, win32.ERROR_IO_PENDING):
#     287                     raise SerialException("ReadFile failed ({!r})".format(ctypes.WinError()))
# --> 288                 result_ok = win32.GetOverlappedResult(
#     289                     self._port_handle,
#     290                     ctypes.byref(self._overlapped_read),
#
# KeyboardInterrupt:

# %%
import serial
import sys
import time

# Open the serial port
ser = serial.Serial('COM7', 9600, timeout=1)

print("Receiver started. Listening for incoming data...")

start_time = time.time()
bytes_received = 0

try:
    while True:
        # Read the incoming data
        data = ser.read(1024)
        
        # Update the byte count
        bytes_received += len(data)

        # Decode the data using ASCII decoding
        decoded_data = data.decode('ascii', errors='ignore')

        # Print the received data
        print(decoded_data, end='')

        # Flush the buffer to ensure timely printing
        sys.stdout.flush()

        # Calculate elapsed time
        elapsed_time = time.time() - start_time

        # Display data rate every second
        if elapsed_time >= 1.0:
            data_rate = bytes_received / elapsed_time  # bytes per second
            print(f"\nData rate: {data_rate:.2f} bytes/second")

            # Reset the counters
            start_time = time.time()
            bytes_received = 0

except KeyboardInterrupt:
    # Graceful exit on keyboard interrupt
    print("\nReceiver stopped.")

finally:
    # Close the serial port
    ser.close()
# Out:
# Receiver started. Listening for incoming data...
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Receiver stopped.

# %%
import serial
import sys
import time

# Open the serial port with a higher baud rate
ser = serial.Serial('COM7', 128000, timeout=1)

print("Receiver started. Listening for incoming data...")

start_time = time.time()
bytes_received = 0

try:
    while True:
        # Read the incoming data
        data = ser.read(1024)
        
        # Update the byte count
        bytes_received += len(data)

        # Decode the data using ASCII decoding
        decoded_data = data.decode('ascii', errors='ignore')

        # Print the received data
        print(decoded_data, end='')

        # Flush the buffer to ensure timely printing
        sys.stdout.flush()

        # Calculate elapsed time
        elapsed_time = time.time() - start_time

        # Display data rate every second
        if elapsed_time >= 1.0:
            data_rate = bytes_received / elapsed_time  # bytes per second
            print(f"\nData rate: {data_rate:.2f} bytes/second")

            # Reset the counters
            start_time = time.time()
            bytes_received = 0

except KeyboardInterrupt:
    # Graceful exit on keyboard interrupt
    print("\nReceiver stopped.")

finally:
    # Close the serial port
    ser.close()
# Out:
# Receiver started. Listening for incoming data...
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 2143.76 bytes/second
#
# Data rate: 891.44 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 671.14 bytes/second
#
# Data rate: 1752.39 bytes/second
#
# Data rate: 97.27 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 59.26 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 8.99 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 65.35 bytes/second
# Data rate: 50.27 bytes/second
#
# Data rate: 690.81 bytes/second
#
# Data rate: 2373.39 bytes/second
#
# Data rate: 1692.23 bytes/second
# Data rate: 2146.29 bytes/second
#
# Data rate: 2414.12 bytes/second
# Data rate: 2379.74 bytes/second
#
# Data rate: 2487.36 bytes/second
# Data rate: 2369.93 bytes/second
#
# Data rate: 2395.23 bytes/second
# Data rate: 2395.86 bytes/second
#
# Data rate: 2452.87 bytes/second
# Data rate: 2401.17 bytes/second
#
# Data rate: 2176.79 bytes/second
# Data rate: 1867.58 bytes/second
#
# Data rate: 2302.23 bytes/second
# Data rate: 2434.25 bytes/second
#
# Data rate: 2350.53 bytes/second
#
# Data rate: 1004.87 bytes/second
#
# Data rate: 688.84 bytes/second
# Data rate: 1375.78 bytes/second
#
# Data rate: 2309.85 bytes/second
#
# Data rate: 1716.51 bytes/second
# Data rate: 2375.33 bytes/second
#
# Data rate: 2452.40 bytes/second
# Data rate: 2372.59 bytes/second
#
# Data rate: 2395.39 bytes/second
#
# Data rate: 870.86 bytes/second
#
# Data rate: 8.91 bytes/second
# Data rate: 1934.90 bytes/second
#
# Data rate: 1703.53 bytes/second
# Data rate: 2437.57 bytes/second
#
# Data rate: 2369.06 bytes/second
# Data rate: 2452.19 bytes/second
#
# Data rate: 2286.26 bytes/second
# Data rate: 2357.75 bytes/second
#
# Data rate: 2346.14 bytes/second
# Data rate: 2420.28 bytes/second
#
# Data rate: 2398.74 bytes/second
# Data rate: 2335.35 bytes/second
#
# Data rate: 2457.39 bytes/second
# Data rate: 2277.39 bytes/second
#
# Data rate: 2397.21 bytes/second
#
# Data rate: 863.28 bytes/second
#
# Data rate: 75.89 bytes/second
# Data rate: 1912.28 bytes/second
#
# Data rate: 2359.87 bytes/second
# Data rate: 2423.66 bytes/second
#
# Data rate: 2396.85 bytes/second
# Data rate: 2429.17 bytes/second
#
# Data rate: 2362.27 bytes/second
# Data rate: 2382.52 bytes/second
#
# Data rate: 2298.18 bytes/second
# Data rate: 2392.47 bytes/second
#
# Data rate: 2456.56 bytes/second
# Data rate: 2398.53 bytes/second
#
# Data rate: 2454.44 bytes/second
# Data rate: 2430.34 bytes/second
#
# Data rate: 2452.47 bytes/second
# Data rate: 2403.46 bytes/second
#
# Data rate: 2460.29 bytes/second
# Data rate: 2425.31 bytes/second
#
# Data rate: 2368.55 bytes/second
#
# Data rate: 752.80 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Data rate: 0.00 bytes/second
#
# Receiver stopped.
